# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat1=pd.read_csv("Global_active_power.csv")

# %%
dat1
# Out:
#                    Datetime  Global_active_power
# 0       2010-01-01 00:00:00                1.790
# 1       2010-01-01 00:01:00                1.780
# 2       2010-01-01 00:02:00                1.780
# 3       2010-01-01 00:03:00                1.746
# 4       2010-01-01 00:04:00                1.686
# ...                     ...                  ...
# 457390  2010-11-26 20:58:00                0.946
# 457391  2010-11-26 20:59:00                0.944
# 457392  2010-11-26 21:00:00                0.938
# 457393  2010-11-26 21:01:00                0.934
# 457394  2010-11-26 21:02:00                0.932
#
# [457395 rows x 2 columns]

# %%
plt.figure(figsize=(18,6))
plt.plot(dat1["Global_active_power"])
plt.show()

# %%
dat2=pd.read_csv("Voltage.csv")

# %%
dat2[0:6].mean()
# Out:
# Voltage    240.225
# dtype: float64

# %%
dataframe --> 0 2010-01-01 00:05:00 240.225

# %%
dat3=pd.read_csv("Global_intensity.csv")
dat3
# Out:
#                    Datetime  Global_intensity
# 0       2010-01-01 00:00:00               7.4
# 1       2010-01-01 00:01:00               7.4
# 2       2010-01-01 00:02:00               7.4
# 3       2010-01-01 00:03:00               7.2
# 4       2010-01-01 00:04:00               7.0
# ...                     ...               ...
# 457390  2010-11-26 20:58:00               4.0
# 457391  2010-11-26 20:59:00               4.0
# 457392  2010-11-26 21:00:00               3.8
# 457393  2010-11-26 21:01:00               3.8
# 457394  2010-11-26 21:02:00               3.8
#
# [457395 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
plt.scatter(dat3["Global_intensity"],dat1["Global_active_power"])
plt.show()

# %%
dat4=pd.read_csv("Global_reactive_power.csv")

# %%
dat4
# Out:
#                    Datetime  Global_reactive_power
# 0       2010-01-01 00:00:00                  0.236
# 1       2010-01-01 00:01:00                  0.234
# 2       2010-01-01 00:02:00                  0.234
# 3       2010-01-01 00:03:00                  0.186
# 4       2010-01-01 00:04:00                  0.102
# ...                     ...                    ...
# 457390  2010-11-26 20:58:00                  0.000
# 457391  2010-11-26 20:59:00                  0.000
# 457392  2010-11-26 21:00:00                  0.000
# 457393  2010-11-26 21:01:00                  0.000
# 457394  2010-11-26 21:02:00                  0.000
#
# [457395 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
plt.scatter(dat3["Global_intensity"],dat4["Global_reactive_power"])
plt.show()

# %%
dat1
# Out:
#                    Datetime  Global_active_power
# 0       2010-01-01 00:00:00                1.790
# 1       2010-01-01 00:01:00                1.780
# 2       2010-01-01 00:02:00                1.780
# 3       2010-01-01 00:03:00                1.746
# 4       2010-01-01 00:04:00                1.686
# ...                     ...                  ...
# 457390  2010-11-26 20:58:00                0.946
# 457391  2010-11-26 20:59:00                0.944
# 457392  2010-11-26 21:00:00                0.938
# 457393  2010-11-26 21:01:00                0.934
# 457394  2010-11-26 21:02:00                0.932
#
# [457395 rows x 2 columns]

# %%
dat1["GAP1000/60"]=dat1["Global_active_power"]*1000/60

# %%
dat1
# Out:
#                    Datetime  Global_active_power       col1  GAP1000/60
# 0       2010-01-01 00:00:00                1.790  29.833333   29.833333
# 1       2010-01-01 00:01:00                1.780  29.666667   29.666667
# 2       2010-01-01 00:02:00                1.780  29.666667   29.666667
# 3       2010-01-01 00:03:00                1.746  29.100000   29.100000
# 4       2010-01-01 00:04:00                1.686  28.100000   28.100000
# ...                     ...                  ...        ...         ...
# 457390  2010-11-26 20:58:00                0.946  15.766667   15.766667
# 457391  2010-11-26 20:59:00                0.944  15.733333   15.733333
# 457392  2010-11-26 21:00:00                0.938  15.633333   15.633333
# 457393  2010-11-26 21:01:00                0.934  15.566667   15.566667
# 457394  2010-11-26 21:02:00                0.932  15.533333   15.533333
#
# [457395 rows x 4 columns]
