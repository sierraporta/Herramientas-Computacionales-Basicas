# %% [markdown]
# # Animación de Gráficos en 2D y 3D
#
# Vamos en esta sesión a aprender a hacer algunas visualizaciones usando animaciones. Esto pudiera ser muy útil algunas veces cuando tenemos presentaciones o queremos darle valor agregado a nuestros resultados, o cuando por ejemplo estamos analizando datos que evolucionan tanto espacial com temporalmente para diversos fenómenos experimentales.

# %%
# cargamos las librerías importantes
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import animation, rc
from IPython.display import HTML
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')
# %matplotlib inline

# %% [markdown]
# Vamos con un pequeño primer ejemplo. Digamos que estamos inetresados en visualizar como se propaga una onda en algún medio. Digamos que estamos interesados en modelar las ondas (oscilaciones) producidas por una pequeña masa unida por un extremo de un resorte y cuyo segundo extremo está sujeto a un punto fijo.
#
# <img src="../figures/masa_resorte.png" style="width: 600px;"/>
#
# La solución de esta ecuación diferencial que describe el fenómeno es que la amplitud o la elongación del resorte varía como $y(t)=A\cos(\omega t)=A\sin(\omega t+\delta)$.

# %%
from gapminder import gapminder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-0c025d3e0938> in <module>
# ----> 1 from gapminder import gapminder
#
# ModuleNotFoundError: No module named 'gapminder'

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation


fig = plt.figure()
#creating a subplot 
ax1 = fig.add_subplot(1,1,1)

def animate(i):
    data = open('stock.txt','r').read()
    lines = data.split('\n')
    xs = []
    ys = []
   
    for line in lines:
        x, y = line.split(',') # Delimiter is comma    
        xs.append(float(x))
        ys.append(float(y))
   
    
    ax1.clear()
    ax1.plot(xs, ys)

    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('Live graph with matplotlib')	
	
    
ani = animation.FuncAnimation(fig, animate, interval=1000) 
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
x = np.arange(0, 12*np.pi, 0.1)
line, = ax.plot(x, np.sin(x))
def animate(i):
    line.set_ydata(np.sin(x+i/50))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=20, blit=False, save_count=150)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()

# %%
ani
# Out:
# <video width="576" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...
